# %%
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd 
import random
import math
import time
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, mean_absolute_error
import operator 
from pmdarima.arima import auto_arima
import pmdarima as pm
from pmdarima.model_selection import train_test_split
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import datetime
from datetime import date
import operator
from matplotlib import pyplot

# %%
confirmed_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv')
confirmed_cases.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  \
# 0        0        0        0  ...     349     367     423     444     484
# 1        0        0        0  ...     361     377     383     400     409
# 2        0        0        0  ...    1320    1423    1468    1572    1666
# 3        0        0        0  ...     501     525     545     564     583
# 4        0        0        0  ...      14      16      17      19      19
#
#    4/10/20  4/11/20  4/12/20  4/13/20  4/14/20
# 0      521      555      607      665      714
# 1      416      433      446      467      475
# 2     1761     1825     1914     1983     2070
# 3      601      601      638      646      659
# 4       19       19       19       19       19
#
# [5 rows x 88 columns]

# %%
deaths_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_global.csv')
deaths_cases.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  \
# 0        0        0        0  ...       7      11      14      14      15
# 1        0        0        0  ...      20      21      22      22      23
# 2        0        0        0  ...     152     173     193     205     235
# 3        0        0        0  ...      18      21      22      23      25
# 4        0        0        0  ...       2       2       2       2       2
#
#    4/10/20  4/11/20  4/12/20  4/13/20  4/14/20
# 0       15       18       18       21       23
# 1       23       23       23       23       24
# 2      256      275      293      313      326
# 3       26       26       29       29       31
# 4        2        2        2        2        2
#
# [5 rows x 88 columns]

# %%
recoveries_cases = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_recovered_global.csv')
recoveries_cases.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/5/20  4/6/20  4/7/20  4/8/20  4/9/20  \
# 0        0        0        0  ...      15      18      18      29      32
# 1        0        0        0  ...     104     116     131     154     165
# 2        0        0        0  ...      90      90     113     237     347
# 3        0        0        0  ...      26      31      39      52      58
# 4        0        0        0  ...       2       2       2       2       2
#
#    4/10/20  4/11/20  4/12/20  4/13/20  4/14/20
# 0       32       32       32       32       40
# 1      182      197      217      232      248
# 2      405      460      591      601      691
# 3       71       71      128      128      128
# 4        2        4        4        4        5
#
# [5 rows x 88 columns]

# %%
colnames = confirmed_cases.columns.values
colnames
# Out:
# array(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20',
#        '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20', '1/28/20',
#        '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20', '2/3/20',
#        '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20',
#        '3/5/20', '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20',
#        '3/11/20', '3/12/20', '3/13/20', '3/14/20', '3/15/20', '3/16/20',
#        '3/17/20', '3/18/20', '3/19/20', '3/20/20', '3/21/20', '3/22/20',
#        '3/23/20', '3/24/20', '3/25/20', '3/26/20', '3/27/20', '3/28/20',
#        '3/29/20', '3/30/20', '3/31/20', '4/1/20', '4/2/20', '4/3/20',
#        '4/4/20', '4/5/20', '4/6/20', '4/7/20', '4/8/20', '4/9/20',
#        '4/10/20', '4/11/20', '4/12/20', '4/13/20', '4/14/20'],
#       dtype=object)

# %%
confirmed = confirmed_cases.loc[:, colnames[4]:colnames[-1]]
deaths = deaths_cases.loc[:, colnames[4]:colnames[-1]]
recoveries = recoveries_cases.loc[:, colnames[4]:colnames[-1]]

# %%
time_date = confirmed.columns.values

# %%
all_days = np.array([i for i in range(len(time_date))]).reshape(-1, 1)

# %% [markdown]
# # Predictions for days ahead

# %%
pred_days_ahead = 2
#pred_days_ahead = 7
#pred_days_ahead = 30
predictions_ahead = np.array([i for i in range(len(time_date)+pred_days_ahead)]).reshape(-1, 1)

predictions_ahead_plus_day = np.array([i for i in range(len(time_date)+pred_days_ahead+1)]).reshape(-1, 1)

# %%
start = datetime.datetime.strptime(colnames[4], "%m/%d/%y")
end = datetime.datetime.strptime(colnames[-1], "%m/%d/%y")
predictions_ahead_dates = [start + datetime.timedelta(days=d) for d in range(len(predictions_ahead_plus_day))]

# %%
countries2 = ['Greece', 'Italy', 'Spain', 'Turkey','Cyprus', 'Switzerland']
countries= confirmed_cases.iloc[0:24,1].tolist()#keep all  country names in a list
countries=countries+countries2
province=confirmed_cases.iloc[0:24,0].tolist()#province list with nan
prov=[float("NaN")]*6
province=province+prov

#countries = ['Algeria','France', 'France','Greece']
#province=[float("NaN"),'Martinique', float("NaN"),float("NaN")]
#province
#'French Guiana','French Polynesia','Guadeloupe','Mayotte','New Caledonia','Reunion','Saint Barthelemy',
       #'St Martin','

# %%
prediction_models = dict()
prediction_models_confirmed = {'SVR': 0}
prediction_models_deaths = {'SVR': 0}
prediction_models_recoveries = {'SVR': 0}

# %%
# Prediction Models

from sklearn import model_selection
from sklearn.svm import SVR
def SVM_regression(train_x, train_y, test_x, test_y, X_test,subpopulation,X_train, Y_train):
    
    # Tune parameters to find optimal ones
   # c = [0.01, 0.1, 1]
   # gamma = [0.01, 0.1, 1]
   #epsilon = [0.01, 0.1, 1]
   #shrinking = [True, False]
    #degree = [3, 4, 5, 6]
  #grid_parameters = {'C': c, 'gamma' : gamma ,'epsilon': epsilon, 'shrinking' : shrinking, 'degree':degree} 
   #regressor = RandomizedSearchCV(SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1, C=0.1), grid_parameters, scoring='neg_mean_squared_error', 
    #                               cv=5)
    
    if (subpopulation == 'confirmed'):
         degree = 3
    elif (subpopulation == 'deaths'):
        degree = 4
    else :
        degree = 5


    regressor = SVR(shrinking=True, kernel='poly',gamma=0.01, epsilon=1,degree=degree, C=0.1)
    regressor.fit(train_x, train_y)
    y_pred = regressor.predict(test_x)
    
    
    if (subpopulation == 'confirmed'):
         prediction_models_confirmed['SVR'] = mean_absolute_error(y_pred, test_y)
    elif (subpopulation == 'deaths'):
        prediction_models_deaths['SVR'] = mean_absolute_error(y_pred, test_y)
    else :
        prediction_models_recoveries['SVR'] = mean_absolute_error(y_pred, test_y)
    
    regressor.fit(X_train, Y_train)
    predictions = regressor.predict(X_test)
    
    return(predictions)

# %%
from sklearn.ensemble import RandomForestRegressor
def RF_regression(train_x, train_y, test_x, test_y,X_test,subpopulation,X_train, Y_train):
    
    # Tune parameters to find optimal ones
    n_estimators = [100, 150, 300]
    grid_parameters = {'n_estimators': n_estimators}
#    regressor = RandomizedSearchCV(RandomForestRegressor(), grid_parameters, scoring='neg_mean_squared_error', 
#                                   cv=3)
    
    regressor = RandomForestRegressor(n_estimators = 200, random_state = 42) 
    regressor.fit(train_x, train_y)
    y_pred = regressor.predict(test_x)
    
    
    if (subpopulation == 'confirmed'):
         prediction_models_confirmed['Random_Forest'] = mean_absolute_error(y_pred, test_y)
    elif (subpopulation == 'deaths'):
        prediction_models_deaths['Random_Forest'] = mean_absolute_error(y_pred, test_y)
    else :
        prediction_models_recoveries['Random_Forest'] = mean_absolute_error(y_pred, test_y)
    
    regressor.fit(X_train, Y_train)
    predictions = regressor.predict(X_test)
    
    return(predictions)

# %%
# Gradient Boosted Regression Trees (GBRT) 
from sklearn.ensemble import GradientBoostingRegressor

def Grad_Boost_regression(train_x, train_y, test_x, test_y,X_test,subpopulation, X_train, Y_train):
   
    # Tune parameters to find optimal ones
    n_estimators = [100, 150, 300]
    loss = ['ls','lad','huber']
    grid_parameters = {'n_estimators': n_estimators}
  #  regressor = RandomizedSearchCV(GradientBoostingRegressor(learning_rate=0.1), grid_parameters, scoring='neg_mean_squared_error', 
 #                                  cv=3)
    
    regressor =  GradientBoostingRegressor(n_estimators=500, learning_rate=0.1,
                                            max_depth=1, random_state=0, loss='huber')
    regressor.fit(train_x, train_y)
    y_pred = regressor.predict(test_x)
    
    
    if (subpopulation == 'confirmed'):
         prediction_models_confirmed['Grad_Tree_Boost'] = mean_absolute_error(y_pred, test_y)
    elif (subpopulation == 'deaths'):
        prediction_models_deaths['Grad_Tree_Boost'] = mean_absolute_error(y_pred, test_y)
    else :
        prediction_models_recoveries['Grad_Tree_Boost'] = mean_absolute_error(y_pred, test_y)
    
    regressor.fit(X_train, Y_train)
    predictions = regressor.predict(X_test)
    
    return(predictions)

# %%
#check if a timeseries is stationary
from statsmodels.tsa.stattools import adfuller
def test_stationarity(timeseries):
    
    #Determing rolling statistics
    rolmean = timeseries.rolling(12).mean()     
    rolstd = timeseries.rolling(12).std()

    #Plot rolling statistics:
    #orig = plt.plot(timeseries, color='blue',label='Original')
    #mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    #std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    #plt.legend(loc='best')
    #plt.title('Rolling Mean & Standard Deviation')
    #plt.show(block=False)
    
    #Perform Dickey-Fuller test:
    #print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    return dfoutput

# %%
def pred_with_arima(timeseries,n_days_ahead):
    
    #find the optimal d 
    diff=timeseries-timeseries.shift(1)
    for d in range(1,10):
        if (test_stationarity(diff.dropna())['p-value']<0.1):
            #print (d) 
            break
        else: 
            d=d+1 
            diff=diff-diff.shift(1)
    #use the arima model to make predictions, use original timeseries with optimal d:
    
    model = pm.auto_arima(timeseries, start_p=0, start_q=0,
                             max_p=4, max_q=4,
                              seasonal=False,
                             d=d, trace=True,
                             error_action='ignore',  # don't want to know if an order does not work
                             suppress_warnings=True,  # don't want convergence warnings
                             stepwise=False)
    print(model)
    forecasts, conf_int =model.predict(n_days_ahead,return_conf_int=True ,alpha=0.05)
    return forecasts , conf_int # returns a tuple, array of forecasts and all conf int

# %%
def Arima_Analysis(region,pred_days_ahead):
   #create a dataframe for timeseries analysis
    date_rng = pd.date_range(start=colnames[4], end=colnames[-1], freq='D') #creates the days
    df = pd.DataFrame(date_rng, columns=['date'])
    df['cases']=np.transpose(region) #this is a dataframe with dates and cases.
    #df['datetime'] = pd.to_datetime(df['date'])
    df = df.set_index('date')
    #df.drop(['date'], axis=1, inplace=True)
    #df.plot( style='k.')
    #pyplot.show()
    df=df[df['cases'] != 0] #remove zeroes, they do not help for analysis. 
    if (len(df)>1):
        pred_ts,conf_int=pred_with_arima(df['cases'],pred_days_ahead)  #.tolist() #this is an array converted to a list
    else:
        pred_ts=np.zeros(pred_days_ahead)
        conf_int=[np.zeros(pred_days_ahead)] * pred_days_ahead
    return pred_ts, conf_int

# %%
# region = confirmed_cases.loc[confirmed_cases['Country/Region'] == 'Greece']
# region =  np.array(region.loc[:, colnames[4]:colnames[-1]])   
# date_rng = pd.date_range(start=colnames[4], end=colnames[-1], freq='D') #creates the days
# df = pd.DataFrame(date_rng, columns=['date'])
# df['cases']=np.transpose(region)
# df = df.set_index('date')
# df=df[df['cases'] != 0]

# %%
#prediction, confidence= Arima_Analysis(region,2)

# %%
#type(pred_with_arima(df['cases'],2)[0])

# %%
import operator
def subpopulation_Analysis(cases,country,province, all_days,predictions_ahead,subpopulation):
    
    pred  = list()
    if pd.isnull(province):
        region = cases.loc[(cases['Country/Region'] == country) & (pd.isnull(cases['Province/State']))]
    else :
        region = cases.loc[(cases['Country/Region'] == country) & (cases['Province/State'] == province)]
    #print(region)
    
    reg =  np.array(region.loc[:, colnames[4]:colnames[-1]])
    region =  np.array(region.loc[:, colnames[4]:colnames[-1]]).reshape(-1, 1)
    
    
    #train_x, test_x, train_y, test_y = model_selection.train_test_split(all_days,region,test_size = 0.04,random_state = 42,shuffle=False)
    
    #pred_svm =  SVM_regression(train_x, train_y.ravel(), test_x, test_y, predictions_ahead,subpopulation,all_days,region.ravel())
    #pred.append(pred_svm)
    
    pred_arima, conf_int=Arima_Analysis(reg,pred_days_ahead)
    #pred.append(pred_svm)
    #pred_RF = RF_regression(train_x, train_y.ravel(), test_x, test_y, predictions_ahead,subpopulation,all_days,region.ravel())
    #pred.append(pred_RF)

    
   # pred_gb =  Grad_Boost_regression(train_x, train_y.ravel(), test_x, test_y, predictions_ahead,subpopulation,all_days,region.ravel())
   # pred.append(pred_gb)


    if (subpopulation == 'confirmed'): 
        if (len(pred_arima)==0):
            min_idx, (min_key, min_val) = min(enumerate(prediction_models_confirmed.items()), key=lambda x: x[1][1])
            best_pred = pred[min_idx]
            conf_int=np.zeros(2)
        else:
            best_pred=pred_arima
            conf_int=conf_int
    elif (subpopulation == 'deaths'):
        if (len(pred_arima)==0):
            min_idx, (min_key, min_val) = min(enumerate(prediction_models_deaths.items()), key=lambda x: x[1][1])
            best_pred = pred[min_idx]
            conf_int=np.zeros(2)
        else:
            best_pred=pred_arima
            conf_int=conf_int
    else :
        if (len(pred_arima)==0):
            min_idx, (min_key, min_val) = min(enumerate(prediction_models_recoveries.items()), key=lambda x: x[1][1])
            best_pred = pred[min_idx]
            conf_int=np.zeros(2)
        else:
            best_pred=pred_arima
            conf_int=conf_int
        
    

    best_pred_ahead = best_pred[-1]
    best_conf_int=conf_int[-1]
    return best_pred_ahead, region, best_pred, best_conf_int

# %%
pred_file = str(2)+"day_prediction_" +  date.today().strftime('%Y-%m-%d') + ".csv"
#pred_file = str(7)+"day_prediction_" + date.today().strftime('%Y-%m-%d') + ".csv"
#pred_file = str(30)+"day_prediction_" + date.today().strftime('%Y-%m-%d') + ".csv"
pred_file
# Out:
# '2day_prediction_2020-04-16.csv'

# %%
columns = ['Province/State','Country','Target/Date','N','low95N','high95N',
          'R','low95R','high95R','D','low95D','high95D','T','low95T','high95T',
           'M','low95M','high95M','C','low95C','high95C']

            

k = 0
for co in range(len(countries)):
    
    total_predictions = pd.DataFrame(columns = columns)
    k = k+1
   
    best_pred_confirmed, region_con, best_pred_con, conf_int_con = subpopulation_Analysis(confirmed_cases,countries[co],province[co],
                                                 all_days,predictions_ahead,"confirmed")
  
    best_pred_deaths, region_d, best_pred_d, conf_int_d = subpopulation_Analysis(deaths_cases,countries[co],province[co],
                                              all_days,predictions_ahead,"deaths")
    
    best_pred_recoveries, region_r, best_pred_r, conf_int_r = subpopulation_Analysis(recoveries_cases,countries[co],province[co],
                                                  all_days,predictions_ahead,"recoveries")
    
    # Mortality rate
    if (conf_int_con[0]==0):
        mort_pred=0
        mort_pred_low=0
        mort_pred_up=0
    else:
        mort_pred  = best_pred_deaths/best_pred_confirmed
        mort_pred_low= conf_int_d[0]/conf_int_con[1]
        mort_pred_up=conf_int_d[1]/conf_int_con[0]
    
    #fix province
    province_name=''
    if (pd.notnull(province[co])) :
        province_name=province[co]
    
    total_predictions = total_predictions.append({'Province/State': province_name,
                                                'Country': countries[co],
                                                'Target/Date': predictions_ahead_dates[-1].strftime('%Y-%m-%d'), 
                                                'N': int(best_pred_confirmed) ,
                                                'low95N':int(conf_int_con[0]),
                                                'high95N': int(conf_int_con[1]),
                                                'R': int(best_pred_recoveries) ,
                                                'low95R' : int(conf_int_r[0]),
                                                'high95R' : int(conf_int_r[1]),
                                                'D': int(best_pred_deaths) ,
                                                'low95D' : int(conf_int_d[0]),
                                                'high95D': int(conf_int_d[1]),
                                                'T': '',
                                                'low95T' : '' ,
                                                'high95T' : '',
                                                'M': mort_pred,
                                                'low95M': mort_pred_low,
                                                'high95M': mort_pred_up ,
                                                'C': '' ,
                                                'low95C': '' ,
                                                'high95C': '' },ignore_index = True)
    
    if (k==1):
        header = True
    else:
        header = False
    
    total_predictions.to_csv(pred_file, sep=',',index = False,  mode='a', header = header)
# Out:
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=429.664, BIC=433.448, Time=0.028 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=395.081, BIC=400.756, Time=0.103 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=392.689, BIC=400.257, Time=0.175 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=393.437, BIC=402.896, Time=0.291 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=398.700, BIC=410.050, Time=0.413 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=404.064, BIC=409.739, Time=0.046 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=392.368, BIC=399.935, Time=0.115 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=394.340, BIC=403.800, Time=0.296 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=395.285, BIC=406.636, Time=0.488 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=397.010, BIC=410.253, Time=0.629 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=395.219, BIC=402.787, Time=0.112 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=394.320, BIC=403.779, Time=0.166 seconds
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=395.456, BIC=406.807, Time=0.419 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=393.312, BIC=406.554, Time=0.423 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=396.971, BIC=406.430, Time=0.218 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=395.749, BIC=407.100, Time=0.380 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=397.025, BIC=410.268, Time=0.601 seconds
# Fit ARIMA: (4, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=398.946, BIC=410.297, Time=0.275 seconds
# Fit ARIMA: (4, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=396.251, BIC=409.493, Time=0.283 seconds
# Total fit time: 5.481 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(1, 2, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=113.394, BIC=115.483, Time=0.011 seconds
# Fit ARIMA: (0, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=94.508, BIC=97.642, Time=0.177 seconds
# Fit ARIMA: (0, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=84.954, BIC=89.132, Time=0.197 seconds
# Fit ARIMA: (0, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=86.872, BIC=92.095, Time=0.476 seconds
# Fit ARIMA: (0, 3, 4)x(0, 0, 0, 0) (constant=True); AIC=88.824, BIC=95.091, Time=0.619 seconds
# Fit ARIMA: (1, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=98.003, BIC=101.137, Time=0.042 seconds
# Fit ARIMA: (1, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=89.107, BIC=93.285, Time=0.467 seconds
# Fit ARIMA: (1, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=86.862, BIC=92.085, Time=0.766 seconds
# Fit ARIMA: (1, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=88.578, BIC=94.845, Time=0.883 seconds
# Fit ARIMA: (1, 3, 4)x(0, 0, 0, 0) (constant=True); AIC=88.104, BIC=95.416, Time=0.954 seconds
# Fit ARIMA: (2, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=98.110, BIC=102.288, Time=0.082 seconds
# Fit ARIMA: (2, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=90.852, BIC=96.075, Time=0.367 seconds
# Fit ARIMA: (2, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=91.444, BIC=97.711, Time=0.314 seconds
# Fit ARIMA: (2, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=91.059, BIC=98.371, Time=0.699 seconds
# Fit ARIMA: (3, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=96.158, BIC=101.380, Time=0.148 seconds
# Fit ARIMA: (3, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=89.206, BIC=95.474, Time=0.563 seconds
# Fit ARIMA: (3, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=89.343, BIC=96.655, Time=0.872 seconds
# Fit ARIMA: (4, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=88.993, BIC=95.260, Time=0.168 seconds
# Fit ARIMA: (4, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=89.745, BIC=97.056, Time=0.665 seconds
# Total fit time: 8.493 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 3, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 5, 0)x(0, 0, 0, 0) (constant=True); AIC=224.582, BIC=227.019, Time=0.020 seconds
# Fit ARIMA: (0, 5, 1)x(0, 0, 0, 0) (constant=True); AIC=199.823, BIC=203.480, Time=0.223 seconds
# Fit ARIMA: (0, 5, 2)x(0, 0, 0, 0) (constant=True); AIC=179.245, BIC=184.121, Time=0.483 seconds
# Fit ARIMA: (0, 5, 3)x(0, 0, 0, 0) (constant=True); AIC=165.918, BIC=172.012, Time=0.396 seconds
# Fit ARIMA: (0, 5, 4)x(0, 0, 0, 0) (constant=True); AIC=163.834, BIC=171.148, Time=1.044 seconds
# Fit ARIMA: (1, 5, 0)x(0, 0, 0, 0) (constant=True); AIC=209.023, BIC=212.679, Time=0.076 seconds
# Fit ARIMA: (1, 5, 1)x(0, 0, 0, 0) (constant=True); AIC=188.185, BIC=193.060, Time=0.240 seconds
# Fit ARIMA: (1, 5, 2)x(0, 0, 0, 0) (constant=True); AIC=172.229, BIC=178.323, Time=0.442 seconds
# Fit ARIMA: (1, 5, 3)x(0, 0, 0, 0) (constant=True); AIC=180.824, BIC=188.137, Time=0.658 seconds
# Fit ARIMA: (1, 5, 4)x(0, 0, 0, 0) (constant=True); AIC=168.629, BIC=177.161, Time=0.850 seconds
# Fit ARIMA: (2, 5, 0)x(0, 0, 0, 0) (constant=True); AIC=193.365, BIC=198.240, Time=0.078 seconds
# Fit ARIMA: (2, 5, 1)x(0, 0, 0, 0) (constant=True); AIC=173.584, BIC=179.678, Time=0.334 seconds
# Fit ARIMA: (2, 5, 2)x(0, 0, 0, 0) (constant=True); AIC=163.379, BIC=170.692, Time=0.536 seconds
# Fit ARIMA: (2, 5, 3)x(0, 0, 0, 0) (constant=True); AIC=164.494, BIC=173.026, Time=0.862 seconds
# Fit ARIMA: (3, 5, 0)x(0, 0, 0, 0) (constant=True); AIC=170.424, BIC=176.519, Time=0.197 seconds
# Fit ARIMA: (3, 5, 1)x(0, 0, 0, 0) (constant=True); AIC=160.968, BIC=168.281, Time=0.719 seconds
# Fit ARIMA: (3, 5, 2)x(0, 0, 0, 0) (constant=True); AIC=163.257, BIC=171.789, Time=0.582 seconds
# Fit ARIMA: (4, 5, 0)x(0, 0, 0, 0) (constant=True); AIC=168.884, BIC=176.198, Time=0.220 seconds
# Fit ARIMA: (4, 5, 1)x(0, 0, 0, 0) (constant=True); AIC=162.962, BIC=171.494, Time=0.741 seconds
# Total fit time: 8.723 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(3, 5, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=251.010, BIC=254.177, Time=0.044 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=240.773, BIC=245.523, Time=0.148 seconds
# Fit ARIMA: (0, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=241.202, BIC=247.536, Time=0.228 seconds
# Fit ARIMA: (0, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=240.141, BIC=248.059, Time=0.305 seconds
# Fit ARIMA: (0, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=242.014, BIC=251.515, Time=0.470 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=236.945, BIC=241.696, Time=0.122 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=238.678, BIC=245.013, Time=0.212 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=240.649, BIC=248.566, Time=0.344 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=241.565, BIC=251.066, Time=0.663 seconds
# Fit ARIMA: (1, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=243.565, BIC=254.649, Time=1.231 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=238.675, BIC=245.009, Time=0.179 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=240.671, BIC=248.588, Time=0.414 seconds
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=242.064, BIC=251.565, Time=0.312 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=243.435, BIC=254.520, Time=0.464 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=240.658, BIC=248.576, Time=0.138 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=241.671, BIC=251.173, Time=0.337 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=240.376, BIC=251.461, Time=0.723 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=241.951, BIC=251.452, Time=0.242 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=243.000, BIC=254.084, Time=0.728 seconds
# Total fit time: 7.363 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(1, 1, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=97.828, BIC=100.880, Time=0.059 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=99.733, BIC=104.312, Time=0.088 seconds
# Fit ARIMA: (0, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=101.727, BIC=107.833, Time=0.132 seconds
# Fit ARIMA: (0, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=97.207, BIC=104.839, Time=0.148 seconds
# Fit ARIMA: (0, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=92.766, BIC=101.925, Time=0.606 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=99.734, BIC=104.313, Time=0.036 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=100.532, BIC=106.637, Time=0.159 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=93.734, BIC=101.366, Time=0.414 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=92.047, BIC=101.205, Time=0.619 seconds
# Fit ARIMA: (1, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=93.828, BIC=104.512, Time=0.703 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=101.733, BIC=107.839, Time=0.082 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=101.858, BIC=109.490, Time=0.165 seconds
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=93.843, BIC=103.002, Time=0.550 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=93.990, BIC=104.675, Time=0.824 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=101.600, BIC=109.231, Time=0.098 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=99.972, BIC=109.130, Time=0.194 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=92.162, BIC=102.847, Time=0.498 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=96.008, BIC=105.166, Time=0.113 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=97.363, BIC=108.047, Time=0.175 seconds
# Total fit time: 5.682 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(1, 1, 3), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=157.822, BIC=160.093, Time=0.011 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=141.487, BIC=144.894, Time=0.143 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=138.540, BIC=143.082, Time=0.340 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=138.762, BIC=144.440, Time=0.414 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=140.751, BIC=147.564, Time=0.437 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=150.411, BIC=153.817, Time=0.042 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=142.011, BIC=146.553, Time=0.429 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=145.480, BIC=151.157, Time=0.727 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=141.254, BIC=148.067, Time=0.894 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=142.603, BIC=150.552, Time=1.467 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=149.260, BIC=153.802, Time=0.142 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=143.514, BIC=149.192, Time=0.789 seconds
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=145.203, BIC=152.016, Time=0.780 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=146.000, BIC=153.949, Time=0.725 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=150.606, BIC=156.283, Time=0.164 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=145.074, BIC=151.887, Time=0.648 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=147.161, BIC=155.109, Time=0.567 seconds
# Fit ARIMA: (4, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=150.128, BIC=156.941, Time=0.123 seconds
# Fit ARIMA: (4, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=144.410, BIC=152.358, Time=0.487 seconds
# Total fit time: 9.388 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 2, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=453.174, BIC=456.917, Time=0.011 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=447.676, BIC=453.289, Time=0.074 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=449.632, BIC=457.116, Time=0.121 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=451.531, BIC=460.887, Time=0.223 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=445.862, BIC=457.089, Time=0.744 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=448.844, BIC=454.457, Time=0.106 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=448.320, BIC=455.805, Time=0.504 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=449.765, BIC=459.121, Time=0.531 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=451.646, BIC=462.873, Time=0.754 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=448.618, BIC=461.716, Time=0.786 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=449.270, BIC=456.755, Time=0.129 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=449.354, BIC=458.710, Time=0.368 seconds
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=450.388, BIC=461.615, Time=0.463 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=450.976, BIC=464.074, Time=0.660 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=450.224, BIC=459.580, Time=0.173 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=451.530, BIC=462.757, Time=0.331 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=449.651, BIC=462.749, Time=0.563 seconds
# Fit ARIMA: (4, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=450.012, BIC=461.240, Time=0.247 seconds
# Fit ARIMA: (4, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=449.912, BIC=463.010, Time=0.670 seconds
# Total fit time: 7.476 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 2, 4), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 4, 0)x(0, 0, 0, 0) (constant=True); AIC=260.237, BIC=263.040, Time=0.016 seconds
# Fit ARIMA: (0, 4, 1)x(0, 0, 0, 0) (constant=True); AIC=229.061, BIC=233.265, Time=0.208 seconds
# Fit ARIMA: (0, 4, 2)x(0, 0, 0, 0) (constant=True); AIC=205.852, BIC=211.456, Time=0.506 seconds
# Fit ARIMA: (0, 4, 3)x(0, 0, 0, 0) (constant=True); AIC=203.094, BIC=210.100, Time=0.517 seconds
# Fit ARIMA: (0, 4, 4)x(0, 0, 0, 0) (constant=True); AIC=203.731, BIC=212.138, Time=0.571 seconds
# Fit ARIMA: (1, 4, 0)x(0, 0, 0, 0) (constant=True); AIC=233.624, BIC=237.828, Time=0.042 seconds
# Fit ARIMA: (1, 4, 1)x(0, 0, 0, 0) (constant=True); AIC=211.198, BIC=216.803, Time=0.223 seconds
# Fit ARIMA: (1, 4, 2)x(0, 0, 0, 0) (constant=True); AIC=202.034, BIC=209.040, Time=0.457 seconds
# Fit ARIMA: (1, 4, 3)x(0, 0, 0, 0) (constant=True); AIC=209.687, BIC=218.095, Time=0.630 seconds
# Fit ARIMA: (1, 4, 4)x(0, 0, 0, 0) (constant=True); AIC=206.573, BIC=216.382, Time=0.681 seconds
# Fit ARIMA: (2, 4, 0)x(0, 0, 0, 0) (constant=True); AIC=222.317, BIC=227.921, Time=0.086 seconds
# Fit ARIMA: (2, 4, 1)x(0, 0, 0, 0) (constant=True); AIC=207.112, BIC=214.118, Time=0.313 seconds
# Fit ARIMA: (2, 4, 2)x(0, 0, 0, 0) (constant=True); AIC=208.962, BIC=217.369, Time=0.312 seconds
 3, 0)x(0, 0, 0, 0) (constant=True); AIC=198.971, BIC=203.637, Time=0.032 seconds
# Fit ARIMA: (1, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=175.146, BIC=181.367, Time=0.278 seconds
# Fit ARIMA: (1, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=167.416, BIC=175.193, Time=0.272 seconds
# Fit ARIMA: (1, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=170.438, BIC=179.770, Time=0.488 seconds
# Fit ARIMA: (1, 3, 4)x(0, 0, 0, 0) (constant=True); AIC=171.684, BIC=182.571, Time=0.704 seconds
# Fit ARIMA: (2, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=181.216, BIC=187.438, Time=0.060 seconds
# Fit ARIMA: (2, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=170.753, BIC=178.529, Time=0.299 seconds
# Fit ARIMA: (2, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=172.361, BIC=181.693, Time=0.425 seconds
# Fit ARIMA: (2, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=170.481, BIC=181.368, Time=0.683 seconds
# Fit ARIMA: (3, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=182.328, BIC=190.105, Time=0.094 seconds
# Fit ARIMA: (3, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=172.670, BIC=182.002, Time=0.442 seconds
# Fit ARIMA: (3, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=174.330, BIC=185.218, Time=0.651 seconds
# Fit ARIMA: (4, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=182.693, BIC=192.026, Time=0.111 seconds
# Fit ARIMA: (4, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=171.222, BIC=182.109, Time=0.614 seconds
# Total fit time: 7.124 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 3, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=304.406, BIC=307.274, Time=0.014 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=306.404, BIC=310.706, Time=0.084 seconds
# Fit ARIMA: (0, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=308.403, BIC=314.139, Time=0.150 seconds
# Fit ARIMA: (0, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=310.399, BIC=317.569, Time=0.205 seconds
# Fit ARIMA: (0, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=312.340, BIC=320.944, Time=0.272 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=306.404, BIC=310.706, Time=0.079 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=308.404, BIC=314.140, Time=0.082 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=310.398, BIC=317.568, Time=0.222 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=312.397, BIC=321.001, Time=0.375 seconds
# Fit ARIMA: (1, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=314.352, BIC=324.390, Time=0.659 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=308.403, BIC=314.139, Time=0.402 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=310.402, BIC=317.572, Time=0.499 seconds
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=311.775, BIC=320.379, Time=1.093 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=313.568, BIC=323.606, Time=0.968 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=310.398, BIC=317.567, Time=0.230 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=312.394, BIC=320.998, Time=0.281 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=313.071, BIC=323.109, Time=0.750 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=312.355, BIC=320.959, Time=0.585 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=314.373, BIC=324.411, Time=0.607 seconds
# Total fit time: 7.579 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 1, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=386.030, BIC=389.552, Time=0.037 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=371.577, BIC=376.860, Time=0.089 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=373.545, BIC=380.589, Time=0.175 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=375.537, BIC=384.343, Time=0.305 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=373.987, BIC=384.554, Time=0.743 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=377.206, BIC=382.490, Time=0.067 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=373.547, BIC=380.591, Time=0.156 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=374.835, BIC=383.641, Time=0.242 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=376.345, BIC=386.912, Time=0.448 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=374.851, BIC=387.180, Time=1.531 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=372.804, BIC=379.848, Time=0.222 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC
seconds
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=64.899, BIC=71.712, Time=0.460 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=62.609, BIC=70.557, Time=0.607 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=65.146, BIC=70.823, Time=0.126 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=61.915, BIC=68.728, Time=0.609 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=63.913, BIC=71.861, Time=0.493 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=64.004, BIC=70.817, Time=0.157 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=65.895, BIC=73.844, Time=0.311 seconds
# Total fit time: 6.357 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 1, 2), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=120.666, BIC=122.937, Time=0.013 seconds
# Fit ARIMA: (0, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=121.795, BIC=125.201, Time=0.039 seconds
# Fit ARIMA: (0, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=122.787, BIC=127.329, Time=0.303 seconds
# Fit ARIMA: (0, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=123.627, BIC=129.305, Time=0.355 seconds
# Fit ARIMA: (0, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=124.776, BIC=131.589, Time=0.344 seconds
# Fit ARIMA: (1, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=121.974, BIC=125.381, Time=0.037 seconds
# Fit ARIMA: (1, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=121.708, BIC=126.250, Time=0.296 seconds
# Fit ARIMA: (1, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=125.038, BIC=130.715, Time=0.166 seconds
# Fit ARIMA: (1, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=126.558, BIC=133.371, Time=0.449 seconds
# Fit ARIMA: (1, 1, 4)x(0, 0, 0, 0) (constant=True); AIC=125.473, BIC=133.421, Time=0.596 seconds
# Fit ARIMA: (2, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=123.772, BIC=128.314, Time=0.082 seconds
# Fit ARIMA: (2, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=125.239, BIC=130.917, Time=0.144 seconds
# Fit ARIMA: (2, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=125.329, BIC=132.142, Time=0.440 seconds
# Fit ARIMA: (2, 1, 3)x(0, 0, 0, 0) (constant=True); AIC=125.088, BIC=133.037, Time=0.529 seconds
# Fit ARIMA: (3, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=125.540, BIC=131.217, Time=0.103 seconds
# Fit ARIMA: (3, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=125.558, BIC=132.371, Time=0.459 seconds
# Fit ARIMA: (3, 1, 2)x(0, 0, 0, 0) (constant=True); AIC=125.804, BIC=133.752, Time=0.743 seconds
# Fit ARIMA: (4, 1, 0)x(0, 0, 0, 0) (constant=True); AIC=125.348, BIC=132.161, Time=0.302 seconds
# Fit ARIMA: (4, 1, 1)x(0, 0, 0, 0) (constant=True); AIC=126.484, BIC=134.432, Time=0.453 seconds
# Total fit time: 5.875 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(0, 1, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=683.761, BIC=687.504, Time=0.013 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=671.323, BIC=676.937, Time=0.136 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=671.717, BIC=679.202, Time=0.152 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=670.884, BIC=680.240, Time=0.335 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=670.576, BIC=681.803, Time=0.240 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=666.688, BIC=672.301, Time=0.080 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=667.950, BIC=675.435, Time=0.204 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=669.731, BIC=679.087, Time=0.220 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=670.496, BIC=681.723, Time=0.352 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=672.107, BIC=685.205, Time=0.875 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=668.253, BIC=675.738, Time=0.141 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=669.877, BIC=679.233, Time=0.324 seconds
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=671.349, BIC=682.576, Time=0.324 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=668.859, BIC=681.957, Time=0.634 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=668.886, BIC=678.242, Time=0.184 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=670.659, BIC=681.886, Time=0.379 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=670.848, BIC=683.946, Time=0.842 seconds
# Fit ARIMA: (4, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=670.432, BIC=681.659, Time=0.320 seconds
# Fit ARIMA: (4, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=672.168, BIC=685.267, Time=0.912 seconds
# Total fit time: 6.689 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(1, 2, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=355.750, BIC=359.025, Time=0.017 seconds
# Fit ARIMA: (0, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=321.405, BIC=326.318, Time=0.150 seconds
# Fit ARIMA: (0, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=308.046, BIC=314.596, Time=0.432 seconds
# Fit ARIMA: (0, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=309.932, BIC=318.120, Time=0.501 seconds
# Fit ARIMA: (0, 3, 4)x(0, 0, 0, 0) (constant=True); AIC=313.412, BIC=323.238, Time=0.805 seconds
# Fit ARIMA: (1, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=335.675, BIC=340.588, Time=0.056 seconds
# Fit ARIMA: (1, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=316.293, BIC=322.843, Time=0.258 seconds
# Fit ARIMA: (1, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=315.833, BIC=324.021, Time=0.355 seconds
# Fit ARIMA: (1, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=309.795, BIC=319.620, Time=0.437 seconds
# Fit ARIMA: (1, 3, 4)x(0, 0, 0, 0) (constant=True); AIC=305.996, BIC=317.459, Time=0.428 seconds
# Fit ARIMA: (2, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=335.638, BIC=342.188, Time=0.099 seconds
# Fit ARIMA: (2, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=316.522, BIC=324.710, Time=0.392 seconds
# Fit ARIMA: (2, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=317.081, BIC=326.906, Time=0.622 seconds
# Fit ARIMA: (2, 3, 3)x(0, 0, 0, 0) (constant=True); AIC=310.227, BIC=321.690, Time=0.878 seconds
# Fit ARIMA: (3, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=305.413, BIC=313.601, Time=0.191 seconds
# Fit ARIMA: (3, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=296.804, BIC=306.629, Time=0.219 seconds
# Fit ARIMA: (3, 3, 2)x(0, 0, 0, 0) (constant=True); AIC=298.139, BIC=309.603, Time=0.406 seconds
# Fit ARIMA: (4, 3, 0)x(0, 0, 0, 0) (constant=True); AIC=298.924, BIC=308.750, Time=0.509 seconds
# Fit ARIMA: (4, 3, 1)x(0, 0, 0, 0) (constant=True); AIC=302.450, BIC=313.913, Time=0.309 seconds
# Total fit time: 7.086 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(3, 3, 1), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
# Fit ARIMA: (0, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=642.789, BIC=646.216, Time=0.017 seconds
# Fit ARIMA: (0, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=616.955, BIC=622.095, Time=0.192 seconds
# Fit ARIMA: (0, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=616.200, BIC=623.054, Time=0.328 seconds
# Fit ARIMA: (0, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=613.954, BIC=622.522, Time=0.433 seconds
# Fit ARIMA: (0, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=615.277, BIC=625.559, Time=0.579 seconds
# Fit ARIMA: (1, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=618.501, BIC=623.642, Time=0.072 seconds
# Fit ARIMA: (1, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=614.927, BIC=621.781, Time=0.225 seconds
# Fit ARIMA: (1, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=616.767, BIC=625.335, Time=0.362 seconds
# Fit ARIMA: (1, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=614.361, BIC=624.642, Time=0.596 seconds
# Fit ARIMA: (1, 2, 4)x(0, 0, 0, 0) (constant=True); AIC=617.953, BIC=629.948, Time=0.750 seconds
# Fit ARIMA: (2, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=616.554, BIC=623.408, Time=0.146 seconds
# Fit ARIMA: (2, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=616.706, BIC=625.274, Time=0.201 seconds
# Fit ARIMA: (2, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=617.820, BIC=628.102, Time=0.296 seconds
# Fit ARIMA: (2, 2, 3)x(0, 0, 0, 0) (constant=True); AIC=613.794, BIC=625.789, Time=0.658 seconds
# Fit ARIMA: (3, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=618.508, BIC=627.076, Time=0.195 seconds
# Fit ARIMA: (3, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=617.007, BIC=627.288, Time=0.679 seconds
# Fit ARIMA: (3, 2, 2)x(0, 0, 0, 0) (constant=True); AIC=616.444, BIC=628.439, Time=0.941 seconds
# Fit ARIMA: (4, 2, 0)x(0, 0, 0, 0) (constant=True); AIC=610.900, BIC=621.181, Time=0.324 seconds
# Fit ARIMA: (4, 2, 1)x(0, 0, 0, 0) (constant=True); AIC=612.595, BIC=624.590, Time=0.324 seconds
# Total fit time: 7.337 seconds
# ARIMA(maxiter=50, method='lbfgs', order=(4, 2, 0), out_of_sample_size=0,
#       scoring='mse', scoring_args=None, seasonal_order=(0, 0, 0, 0),
#       start_params=None, suppress_warnings=True, trend=None,
#       with_intercept=True)
